# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
print (cities)

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = f'{url}&q={city.replace(" ","+")}'
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity'] 
        cloudiness = city_weather['clouds']['all'] 
        wind_speed = city_weather['wind']['speed'] 
        country = city_weather['sys']['country'] 
        description = city_weather['weather'][0]['description']
        


        # Append the city information into the city_data list
        city_data.append({
            "City": city.title(),
            "Lat": lat,
            "Lng": lng,
            "Max Temp": max_temp,
            "Humidity": humidity,
            "Cloudiness": cloudiness,
            "Wind Speed": wind_speed,
            "Country": country,
            "Description": description
        })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rafai
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | isangel
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | luanda
# Processing Record 7 of Set 1 | rongcheng
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | siguiri
# Processing Record 12 of Set 1 | zig
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | susangerd
# Processing Record 15 of Set 1 | hofn
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | emborion
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | sinnamary
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | sao joao da barra
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | tyup
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | high level
# Processing Record 40 of Set 1 | progreso
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | the pas
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | sao filipe
# Processing Record 45 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 1 | faya
# Processing Record 47 of Set 1 | ambovombe
# Processing Record 48 of Set 1 | sioux lookout
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | rypefjord
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | urucara
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | arman
# Processing Record 11 of Set 2 | broken arrow
# Processing Record 12 of Set 2 | torbay
# Processing Record 13 of Set 2 | sawakin
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | gizo
# Processing Record 16 of Set 2 | honiara
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | moba
# Processing Record 19 of Set 2 | pochutla
# Processing Record 20 of Set 2 | senneterre
# Processing Record 21 of Set 2 | kununurra
# Processing Record 22 of Set 2 | honningsvag
# Processing Record 23 of Set 2 | monrovia
# Processing Record 24 of Set 2 | nileshwar
# Processing Record 25 of Set 2 | bykovo
# Processing Record 26 of Set 2 | richards bay
# Processing Record 27 of Set 2 | sturgeon bay
# Processing Record 28 of Set 2 | east london
# Processing Record 29 of Set 2 | borazjan
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | beringovskiy
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | evensk
# Processing Record 35 of Set 2 | tabukiniberu
# City not found. Skipping...
# Processing Record 36 of Set 2 | binuntucan
# City not found. Skipping...
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | port macquarie
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | mandan
# Processing Record 44 of Set 2 | jawhar
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | straumen
# Processing Record 47 of Set 2 | horizontina
# Processing Record 48 of Set 2 | tura
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | barcelona
# Processing Record 1 of Set 3 | beamsville
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | zalesovo
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | katobu
# Processing Record 7 of Set 3 | biu
# Processing Record 8 of Set 3 | alofi
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | ponta delgada
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | bardiyah
# Processing Record 14 of Set 3 | jodar
# Processing Record 15 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 3 | innisfail
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | tucurui
# Processing Record 19 of Set 3 | saint-ambroise
# Processing Record 20 of Set 3 | san vicente de canete
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | buala
# Processing Record 24 of Set 3 | sisimiut
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | thinadhoo
# Processing Record 27 of Set 3 | skala
# Processing Record 28 of Set 3 | mahibadhoo
# Processing Record 29 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | vao
# Processing Record 32 of Set 3 | sept-iles
# Processing Record 33 of Set 3 | marigot
# Processing Record 34 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | grand gaube
# Processing Record 40 of Set 3 | arlit
# Processing Record 41 of Set 3 | sorland
# Processing Record 42 of Set 3 | praia
# Processing Record 43 of Set 3 | mount gambier
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 3 | ouango
# Processing Record 47 of Set 3 | clonakilty
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | kutum
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | tzucacab
# Processing Record 2 of Set 4 | yakeshi
# Processing Record 3 of Set 4 | berbera
# Processing Record 4 of Set 4 | lazurne
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | bambanglipuro
# Processing Record 7 of Set 4 | honggang
# Processing Record 8 of Set 4 | paso del macho
# Processing Record 9 of Set 4 | pathein
# Processing Record 10 of Set 4 | mudgee
# Processing Record 11 of Set 4 | longyearbyen
# Processing Record 12 of Set 4 | afua
# Processing Record 13 of Set 4 | akniste
# Processing Record 14 of Set 4 | port keats
# Processing Record 15 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 16 of Set 4 | la asuncion
# Processing Record 17 of Set 4 | camapua
# Processing Record 18 of Set 4 | bileca
# Processing Record 19 of Set 4 | vila franca do campo
# Processing Record 20 of Set 4 | gamba
# Processing Record 21 of Set 4 | oistins
# Processing Record 22 of Set 4 | luorong
# Processing Record 23 of Set 4 | inhambane
# Processing Record 24 of Set 4 | ouahigouya
# Processing Record 25 of Set 4 | mancio lima
# Processing Record 26 of Set 4 | port augusta
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | tacuarembo
# Processing Record 31 of Set 4 | sao jose da coroa grande
# Processing Record 32 of Set 4 | flinders
# Processing Record 33 of Set 4 | crotone
# Processing Record 34 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | shurugwi
# Processing Record 36 of Set 4 | elko
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | san quintin
# Processing Record 39 of Set 4 | tasiilaq
# Processing Record 40 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 41 of Set 4 | pangnirtung
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | ayna
# Processing Record 44 of Set 4 | port lincoln
# Processing Record 45 of Set 4 | kem
# Processing Record 46 of Set 4 | nsukka
# Processing Record 47 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | melfi
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | kenai
# Processing Record 3 of Set 5 | xique-xique
# Processing Record 4 of Set 5 | port hedland
# Processing Record 5 of Set 5 | anadyr
# Processing Record 6 of Set 5 | taos
# Processing Record 7 of Set 5 | tombouctou
# Processing Record 8 of Set 5 | puerto carreno
# Processing Record 9 of Set 5 | balezino
# Processing Record 10 of Set 5 | eureka
# Processing Record 11 of Set 5 | chernoyerkovskaya
# Processing Record 12 of Set 5 | ust-kuyga
# Processing Record 13 of Set 5 | albany
# Processing Record 14 of Set 5 | ixtapa
# Processing Record 15 of Set 5 | kommunar
# Processing Record 16 of Set 5 | rawson
# Processing Record 17 of Set 5 | paramirim
# Processing Record 18 of Set 5 | irtyshskiy
# Processing Record 19 of Set 5 | suluq
# Processing Record 20 of Set 5 | dunedin
# Processing Record 21 of Set 5 | amurrio
# Processing Record 22 of Set 5 | kodiak
# Processing Record 23 of Set 5 | ginda
# Processing Record 24 of Set 5 | togitsu
# Processing Record 25 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 5 | solnechnyy
# Processing Record 27 of Set 5 | starodub
# Processing Record 28 of Set 5 | chapais
# Processing Record 29 of Set 5 | lecce
# Processing Record 30 of Set 5 | nelson bay
# Processing Record 31 of Set 5 | dalbandin
# Processing Record 32 of Set 5 | caravelas
# Processing Record 33 of Set 5 | ribeira grande
# Processing Record 34 of Set 5 | ilhabela
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | muzhi
# Processing Record 39 of Set 5 | atambua
# Processing Record 40 of Set 5 | cherskiy
# Processing Record 41 of Set 5 | tokmak
# Processing Record 42 of Set 5 | ahipara
# Processing Record 43 of Set 5 | porosozero
# Processing Record 44 of Set 5 | dianopolis
# City not found. Skipping...
# Processing Record 45 of Set 5 | mehamn
# Processing Record 46 of Set 5 | balsta
# Processing Record 47 of Set 5 | gloversville
# Processing Record 48 of Set 5 | mandera
# Processing Record 49 of Set 5 | malumfashi
# Processing Record 50 of Set 5 | alta floresta
# Processing Record 1 of Set 6 | kapit
# Processing Record 2 of Set 6 | sungai besar
# Processing Record 3 of Set 6 | jadu
# Processing Record 4 of Set 6 | majagual
# Processing Record 5 of Set 6 | salinas
# Processing Record 6 of Set 6 | adrar
# Processing Record 7 of Set 6 | aguimes
# Processing Record 8 of Set 6 | conceicao do araguaia
# Processing Record 9 of Set 6 | cayenne
# Processing Record 10 of Set 6 | flin flon
# Processing Record 11 of Set 6 | aitape
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | grafton
# Processing Record 14 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 6 | liverpool
# Processing Record 16 of Set 6 | karsun
# Processing Record 17 of Set 6 | norman wells
# Processing Record 18 of Set 6 | pitimbu
# Processing Record 19 of Set 6 | los llanos de aridane
# Processing Record 20 of Set 6 | bandar-e lengeh
# Processing Record 21 of Set 6 | port elizabeth
# Processing Record 22 of Set 6 | waitati
# Processing Record 23 of Set 6 | joshimath
# Processing Record 24 of Set 6 | katherine
# Processing Record 25 of Set 6 | chiang mai
# Processing Record 26 of Set 6 | roald
# Processing Record 27 of Set 6 | tazovskiy
# Processing Record 28 of Set 6 | boa vista
# Processing Record 29 of Set 6 | sur
# Processing Record 30 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 6 | souillac
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | kahului
# Processing Record 34 of Set 6 | bengkulu
# Processing Record 35 of Set 6 | madimba
# Processing Record 36 of Set 6 | avera
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | kalmunai
# Processing Record 39 of Set 6 | pontes e lacerda
# Processing Record 40 of Set 6 | almaznyy
# Processing Record 41 of Set 6 | magdagachi
# Processing Record 42 of Set 6 | omsukchan
# Processing Record 43 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 44 of Set 6 | tamandare
# Processing Record 45 of Set 6 | butembo
# Processing Record 46 of Set 6 | oksfjord
# Processing Record 47 of Set 6 | broome
# Processing Record 48 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 6 | taunggyi
# Processing Record 50 of Set 6 | christchurch
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 2 of Set 7 | tautira
# Processing Record 3 of Set 7 | novobirilyussy
# Processing Record 4 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 7 | tahta
# Processing Record 6 of Set 7 | lesogorsk
# Processing Record 7 of Set 7 | acapulco
# Processing Record 8 of Set 7 | felanitx
# Processing Record 9 of Set 7 | coihaique
# Processing Record 10 of Set 7 | uyemskiy
# Processing Record 11 of Set 7 | aneho
# Processing Record 12 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 7 | gainesville
# Processing Record 14 of Set 7 | portland
# Processing Record 15 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 7 | lunino
# Processing Record 17 of Set 7 | krasnogorskoye
# Processing Record 18 of Set 7 | shingu
# Processing Record 19 of Set 7 | devils lake
# Processing Record 20 of Set 7 | warangal
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 7 | otaru
# Processing Record 24 of Set 7 | laguna
# Processing Record 25 of Set 7 | meulaboh
# Processing Record 26 of Set 7 | basco
# Processing Record 27 of Set 7 | vredendal
# Processing Record 28 of Set 7 | ilulissat
# Processing Record 29 of Set 7 | turukhansk
# Processing Record 30 of Set 7 | acajutla
# Processing Record 31 of Set 7 | mogok
# Processing Record 32 of Set 7 | nguruka
# Processing Record 33 of Set 7 | chulman
# Processing Record 34 of Set 7 | shelburne
# Processing Record 35 of Set 7 | gayny
# Processing Record 36 of Set 7 | te anau
# Processing Record 37 of Set 7 | leningradskiy
# Processing Record 38 of Set 7 | ostersund
# Processing Record 39 of Set 7 | lethem
# Processing Record 40 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 7 | kavaratti
# Processing Record 42 of Set 7 | marsh harbour
# Processing Record 43 of Set 7 | xining
# Processing Record 44 of Set 7 | inirida
# Processing Record 45 of Set 7 | willowmore
# Processing Record 46 of Set 7 | necochea
# Processing Record 47 of Set 7 | opuwo
# Processing Record 48 of Set 7 | kakonko
# Processing Record 49 of Set 7 | tommot
# Processing Record 50 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 8 | lima
# Processing Record 2 of Set 8 | hami
# Processing Record 3 of Set 8 | nara
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | codrington
# Processing Record 6 of Set 8 | surt
# Processing Record 7 of Set 8 | victoria
# Processing Record 8 of Set 8 | vestmannaeyjar
# Processing Record 9 of Set 8 | newport
# Processing Record 10 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 11 of Set 8 | talnakh
# Processing Record 12 of Set 8 | kaitangata
# Processing Record 13 of Set 8 | xinyu
# Processing Record 14 of Set 8 | serowe
# Processing Record 15 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 8 | meadow lake
# Processing Record 17 of Set 8 | kruisfontein
# Processing Record 18 of Set 8 | wanning
# Processing Record 19 of Set 8 | bilma
# Processing Record 20 of Set 8 | qaqortoq
# Processing Record 21 of Set 8 | ekibastuz
# Processing Record 22 of Set 8 | nouadhibou
# Processing Record 23 of Set 8 | goure
# Processing Record 24 of Set 8 | narsaq
# Processing Record 25 of Set 8 | iqaluit
# Processing Record 26 of Set 8 | teya
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | sakakah
# Processing Record 29 of Set 8 | goba
# Processing Record 30 of Set 8 | irbeyskoye
# Processing Record 31 of Set 8 | bestobe
# Processing Record 32 of Set 8 | atar
# Processing Record 33 of Set 8 | guerrero negro
# Processing Record 34 of Set 8 | polunochnoye
# Processing Record 35 of Set 8 | ugoofaaru
# Processing Record 36 of Set 8 | pocatello
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | padang
# Processing Record 39 of Set 8 | promyshlennaya
# Processing Record 40 of Set 8 | beloha
# Processing Record 41 of Set 8 | skibbereen
# Processing Record 42 of Set 8 | faanui
# Processing Record 43 of Set 8 | canete
# Processing Record 44 of Set 8 | ponta do sol
# Processing Record 45 of Set 8 | garowe
# Processing Record 46 of Set 8 | touros
# Processing Record 47 of Set 8 | san luis
# Processing Record 48 of Set 8 | bambous virieux
# Processing Record 49 of Set 8 | roswell
# Processing Record 50 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 9 | verkhoyansk
# Processing Record 2 of Set 9 | lazaro cardenas
# Processing Record 3 of Set 9 | jinka
# Processing Record 4 of Set 9 | taltal
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | salvador
# Processing Record 7 of Set 9 | athabasca
# Processing Record 8 of Set 9 | awka
# Processing Record 9 of Set 9 | kirakira
# Processing Record 10 of Set 9 | plered
# City not found. Skipping...
# Processing Record 11 of Set 9 | ayagoz
# Processing Record 12 of Set 9 | krasyukovskaya
# Processing Record 13 of Set 9 | grand-lahou
# Processing Record 14 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | molteno
# Processing Record 17 of Set 9 | gigmoto
# Processing Record 18 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 9 | bassano
# Processing Record 20 of Set 9 | iglesias
# Processing Record 21 of Set 9 | union
# Processing Record 22 of Set 9 | along
# Processing Record 23 of Set 9 | mirante do paranapanema
# Processing Record 24 of Set 9 | aripuana
# Processing Record 25 of Set 9 | erzin
# Processing Record 26 of Set 9 | bandarbeyla
# Processing Record 27 of Set 9 | mocuba
# Processing Record 28 of Set 9 | hervey bay
# Processing Record 29 of Set 9 | strai
# Processing Record 30 of Set 9 | ostrovnoy
# Processing Record 31 of Set 9 | riyadh
# Processing Record 32 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 9 | mezen
# Processing Record 34 of Set 9 | bennington
# Processing Record 35 of Set 9 | namatanai
# Processing Record 36 of Set 9 | fairbanks
# Processing Record 37 of Set 9 | esplanada
# Processing Record 38 of Set 9 | hasaki
# Processing Record 39 of Set 9 | ostrogozhsk
# Processing Record 40 of Set 9 | imeni babushkina
# Processing Record 41 of Set 9 | berlevag
# Processing Record 42 of Set 9 | nanga eboko
# Processing Record 43 of Set 9 | nantucket
# Processing Record 44 of Set 9 | kushima
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | merida
# Processing Record 47 of Set 9 | veliko gradiste
# Processing Record 48 of Set 9 | aklavik
# Processing Record 49 of Set 9 | busembatia
# Processing Record 50 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 10 | cap-aux-meules
# Processing Record 2 of Set 10 | kysyl-syr
# Processing Record 3 of Set 10 | palana
# Processing Record 4 of Set 10 | vilyuysk
# Processing Record 5 of Set 10 | suratgarh
# Processing Record 6 of Set 10 | insar
# Processing Record 7 of Set 10 | mendi
# Processing Record 8 of Set 10 | tukrah
# Processing Record 9 of Set 10 | carnarvon
# Processing Record 10 of Set 10 | orlik
# Processing Record 11 of Set 10 | kapuskasing
# Processing Record 12 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 10 | kulykiv
# Processing Record 14 of Set 10 | valparaiso
# Processing Record 15 of Set 10 | visby
# Processing Record 16 of Set 10 | kasempa
# Processing Record 17 of Set 10 | jumla
# Processing Record 18 of Set 10 | araouane
# Processing Record 19 of Set 10 | orchard homes
# Processing Record 20 of Set 10 | belaya gora
# Processing Record 21 of Set 10 | poum
# Processing Record 22 of Set 10 | lorengau
# Processing Record 23 of Set 10 | bonfim
# Processing Record 24 of Set 10 | yuzhne
# Processing Record 25 of Set 10 | okhotsk
# Processing Record 26 of Set 10 | mlyniv
# Processing Record 27 of Set 10 | abu kamal
# Processing Record 28 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 29 of Set 10 | verkhnyaya sinyachikha
# Processing Record 30 of Set 10 | dawlatabad
# Processing Record 31 of Set 10 | ossora
# Processing Record 32 of Set 10 | eau claire
# Processing Record 33 of Set 10 | labuhan
# Processing Record 34 of Set 10 | nuevo progreso
# Processing Record 35 of Set 10 | bornheim
# Processing Record 36 of Set 10 | burnie
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | walvis bay
# Processing Record 39 of Set 10 | dzilam gonzalez
# Processing Record 40 of Set 10 | vila velha
# Processing Record 41 of Set 10 | hualmay
# Processing Record 42 of Set 10 | deputatskiy
# Processing Record 43 of Set 10 | esperance
# Processing Record 44 of Set 10 | adre
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | balkanabat
# Processing Record 47 of Set 10 | zyryanka
# Processing Record 48 of Set 10 | kodinsk
# Processing Record 49 of Set 10 | pisco
# Processing Record 50 of Set 10 | vostok
# Processing Record 1 of Set 11 | taoudenni
# Processing Record 2 of Set 11 | coahuayana
# Processing Record 3 of Set 11 | newcastle
# Processing Record 4 of Set 11 | saint-pierre
# Processing Record 5 of Set 11 | saint-georges
# Processing Record 6 of Set 11 | loudi
# Processing Record 7 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 11 | yumen
# Processing Record 9 of Set 11 | brattleboro
# Processing Record 10 of Set 11 | ucluelet
# Processing Record 11 of Set 11 | zhezkazgan
# Processing Record 12 of Set 11 | kaeo
# Processing Record 13 of Set 11 | brownsville
# Processing Record 14 of Set 11 | yerbogachen
# Processing Record 15 of Set 11 | kitimat
# Processing Record 16 of Set 11 | vung tau
# Processing Record 17 of Set 11 | jamame
# Processing Record 18 of Set 11 | abha
# Processing Record 19 of Set 11 | port shepstone
# Processing Record 20 of Set 11 | dourados
# Processing Record 21 of Set 11 | kloulklubed
# Processing Record 22 of Set 11 | tessalit
# Processing Record 23 of Set 11 | singkang
# Processing Record 24 of Set 11 | huangchuan
# Processing Record 25 of Set 11 | dubbo
# Processing Record 26 of Set 11 | khani
# Processing Record 27 of Set 11 | ambanja
# Processing Record 28 of Set 11 | russkaya polyana
# Processing Record 29 of Set 11 | pasinler
# Processing Record 30 of Set 11 | gwadar
# Processing Record 31 of Set 11 | lavrentiya
# Processing Record 32 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 11 | sao gabriel da cachoeira
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | buraydah
# Processing Record 36 of Set 11 | sosnovo-ozerskoye
# Processing Record 37 of Set 11 | birin
# Processing Record 38 of Set 11 | nemuro
# Processing Record 39 of Set 11 | jibuti
# Processing Record 40 of Set 11 | kerewan
# Processing Record 41 of Set 11 | vardo
# Processing Record 42 of Set 11 | doctor arroyo
# Processing Record 43 of Set 11 | mayumba
# Processing Record 44 of Set 11 | neratovice
# Processing Record 45 of Set 11 | wajima
# Processing Record 46 of Set 11 | moindou
# Processing Record 47 of Set 11 | san vicente
# Processing Record 48 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 11 | mount hagen
# Processing Record 50 of Set 11 | dongsheng
# Processing Record 1 of Set 12 | south sioux city
# Processing Record 2 of Set 12 | yar-sale
# Processing Record 3 of Set 12 | jieshi
# Processing Record 4 of Set 12 | bubaque
# Processing Record 5 of Set 12 | ulladulla
# Processing Record 6 of Set 12 | manitouwadge
# Processing Record 7 of Set 12 | sterling
# Processing Record 8 of Set 12 | arua
# Processing Record 9 of Set 12 | zalantun
# Processing Record 10 of Set 12 | polovinnoye
# Processing Record 11 of Set 12 | tukan
# Processing Record 12 of Set 12 | trofors
# Processing Record 13 of Set 12 | ketchikan
# Processing Record 14 of Set 12 | sitka
# Processing Record 15 of Set 12 | bataipora
# Processing Record 16 of Set 12 | dingle
# Processing Record 17 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 12 | san jose
# Processing Record 19 of Set 12 | martapura
# Processing Record 20 of Set 12 | darhan
# Processing Record 21 of Set 12 | pasighat
# Processing Record 22 of Set 12 | ferzikovo
# Processing Record 23 of Set 12 | ouesso
# Processing Record 24 of Set 12 | waingapu
# Processing Record 25 of Set 12 | aleksandrov gay
# Processing Record 26 of Set 12 | itarema
# Processing Record 27 of Set 12 | corinto
# Processing Record 28 of Set 12 | severnoye
# Processing Record 29 of Set 12 | novopokrovka
# Processing Record 30 of Set 12 | raga
# Processing Record 31 of Set 12 | katsuura
# Processing Record 32 of Set 12 | santa cruz
# Processing Record 33 of Set 12 | mangai
# Processing Record 34 of Set 12 | manta
# Processing Record 35 of Set 12 | husavik
# Processing Record 36 of Set 12 | pljevlja
# Processing Record 37 of Set 12 | somerset east
# Processing Record 38 of Set 12 | vestmanna
# Processing Record 39 of Set 12 | sabzevar
# Processing Record 40 of Set 12 | russell
# Processing Record 41 of Set 12 | euclides da cunha
# Processing Record 42 of Set 12 | svetlogorsk
# Processing Record 43 of Set 12 | marabba
# Processing Record 44 of Set 12 | anupgarh
# Processing Record 45 of Set 12 | yulara
# Processing Record 46 of Set 12 | ensley
# Processing Record 47 of Set 12 | korla
# Processing Record 48 of Set 12 | tikrit
# Processing Record 49 of Set 12 | baykit
# Processing Record 50 of Set 12 | launceston
# Processing Record 1 of Set 13 | lomas de sargentillo
# Processing Record 2 of Set 13 | price
# Processing Record 3 of Set 13 | compiegne
# Processing Record 4 of Set 13 | samarai
# Processing Record 5 of Set 13 | ahuimanu
# Processing Record 6 of Set 13 | camacha
# Processing Record 7 of Set 13 | melito di porto salvo
# Processing Record 8 of Set 13 | san patricio
# Processing Record 9 of Set 13 | san juan
# Processing Record 10 of Set 13 | amahai
# Processing Record 11 of Set 13 | pombas
# Processing Record 12 of Set 13 | pavino
# Processing Record 13 of Set 13 | chernyshevskiy
# Processing Record 14 of Set 13 | najran
# Processing Record 15 of Set 13 | kedarnath
# City not found. Skipping...
# Processing Record 16 of Set 13 | palmer
# Processing Record 17 of Set 13 | tual
# Processing Record 18 of Set 13 | alvinopolis
# Processing Record 19 of Set 13 | roseburg
# Processing Record 20 of Set 13 | mettur
# Processing Record 21 of Set 13 | saint-marc
# Processing Record 22 of Set 13 | aykhal
# Processing Record 23 of Set 13 | le vauclin
# Processing Record 24 of Set 13 | iisalmi
# Processing Record 25 of Set 13 | warrington
# Processing Record 26 of Set 13 | port hardy
# Processing Record 27 of Set 13 | muroran
# Processing Record 28 of Set 13 | tabas
# Processing Record 29 of Set 13 | kavieng
# Processing Record 30 of Set 13 | matara
# Processing Record 31 of Set 13 | torit
# Processing Record 32 of Set 13 | bathsheba
# Processing Record 33 of Set 13 | lianzhou
# Processing Record 34 of Set 13 | usinsk
# Processing Record 35 of Set 13 | berdigestyakh
# Processing Record 36 of Set 13 | uray
# Processing Record 37 of Set 13 | teguise
# Processing Record 38 of Set 13 | grand-bourg
# Processing Record 39 of Set 13 | taksimo
# Processing Record 40 of Set 13 | mattru
# Processing Record 41 of Set 13 | andenes
# Processing Record 42 of Set 13 | olinda
# Processing Record 43 of Set 13 | natchitoches
# Processing Record 44 of Set 13 | hazorasp
# Processing Record 45 of Set 13 | parfino
# Processing Record 46 of Set 13 | ishigaki
# Processing Record 47 of Set 13 | akdagmadeni
# Processing Record 48 of Set 13 | jalu
# Processing Record 49 of Set 13 | krasnoselkup
# Processing Record 50 of Set 13 | monster
# Processing Record 1 of Set 14 | san francisco
# Processing Record 2 of Set 14 | sefophe
# Processing Record 3 of Set 14 | jasper
# Processing Record 4 of Set 14 | awjilah
# Processing Record 5 of Set 14 | tawang
# Processing Record 6 of Set 14 | verkhnevilyuysk
# Processing Record 7 of Set 14 | haines junction
# Processing Record 8 of Set 14 | fort nelson
# Processing Record 9 of Set 14 | vilhena
# Processing Record 10 of Set 14 | nipawin
# Processing Record 11 of Set 14 | satana
# Processing Record 12 of Set 14 | mosquera
# Processing Record 13 of Set 14 | agadez
# Processing Record 14 of Set 14 | nichinan
# Processing Record 15 of Set 14 | sfantu gheorghe
# Processing Record 16 of Set 14 | shenjiamen
# Processing Record 17 of Set 14 | sarkikaraagac
# Processing Record 18 of Set 14 | north bend
# Processing Record 19 of Set 14 | albury
# Processing Record 20 of Set 14 | sola
# Processing Record 21 of Set 14 | mawlaik
# Processing Record 22 of Set 14 | suamico
# Processing Record 23 of Set 14 | bodden town
# Processing Record 24 of Set 14 | ye
# City not found. Skipping...
# Processing Record 25 of Set 14 | kungurtug
# Processing Record 26 of Set 14 | vila
# Processing Record 27 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 14 | moose factory
# Processing Record 30 of Set 14 | dothan
# Processing Record 31 of Set 14 | ambon
# Processing Record 32 of Set 14 | heihe
# Processing Record 33 of Set 14 | alipur chatha
# Processing Record 34 of Set 14 | leiyang
# Processing Record 35 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 36 of Set 14 | cagli
# Processing Record 37 of Set 14 | san ramon
# Processing Record 38 of Set 14 | acarau
# Processing Record 39 of Set 14 | hovd
# Processing Record 40 of Set 14 | noumea
# Processing Record 41 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 14 | komsomolskiy
# Processing Record 43 of Set 14 | delmas
# Processing Record 44 of Set 14 | sovetskaya gavan
# Processing Record 45 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 14 | ovalle
# Processing Record 47 of Set 14 | diffa
# Processing Record 48 of Set 14 | havoysund
# Processing Record 49 of Set 14 | chhukha
# City not found. Skipping...
# Processing Record 50 of Set 14 | lalmohan
# Processing Record 1 of Set 15 | havre-saint-pierre
# Processing Record 2 of Set 15 | zhangye
# Processing Record 3 of Set 15 | bayan
# Processing Record 4 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 5 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 15 | fortuna foothills
# Processing Record 7 of Set 15 | neryungri
# Processing Record 8 of Set 15 | at-bashi
# Processing Record 9 of Set 15 | benalla
# Processing Record 10 of Set 15 | gasa
# Processing Record 11 of Set 15 | gao
# Processing Record 12 of Set 15 | kathu
# Processing Record 13 of Set 15 | tatawin
# Processing Record 14 of Set 15 | bend
# Processing Record 15 of Set 15 | usvyaty
# Processing Record 16 of Set 15 | thunder bay
# Processing Record 17 of Set 15 | qui nhon
# Processing Record 18 of Set 15 | belmonte
# Processing Record 19 of Set 15 | rock sound
# Processing Record 20 of Set 15 | kuytun
# Processing Record 21 of Set 15 | serebryansk
# Processing Record 22 of Set 15 | naryan-mar
# Processing Record 23 of Set 15 | oussouye
# Processing Record 24 of Set 15 | rincon
# Processing Record 25 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 26 of Set 15 | preston
# Processing Record 27 of Set 15 | gari
# Processing Record 28 of Set 15 | yangambi
# Processing Record 29 of Set 15 | batagay-alyta
# Processing Record 30 of Set 15 | lodingen
# Processing Record 31 of Set 15 | varhaug
# Processing Record 32 of Set 15 | cooma
# Processing Record 33 of Set 15 | lander
# Processing Record 34 of Set 15 | moerai
# Processing Record 35 of Set 15 | bolshoye nagatkino
# Processing Record 36 of Set 15 | iracoubo
# Processing Record 37 of Set 15 | guatire
# Processing Record 38 of Set 15 | praia da vitoria
# Processing Record 39 of Set 15 | halifax
# Processing Record 40 of Set 15 | mizan teferi
# Processing Record 41 of Set 15 | sirfa
# City not found. Skipping...
# Processing Record 42 of Set 15 | teluk nibung
# Processing Record 43 of Set 15 | solntsevo
# Processing Record 44 of Set 15 | shihezi
# Processing Record 45 of Set 15 | irbil
# Processing Record 46 of Set 15 | humberto de campos
# Processing Record 47 of Set 15 | victor harbor
# Processing Record 48 of Set 15 | bucerias
# Processing Record 49 of Set 15 | marovoay
# Processing Record 50 of Set 15 | pelym
# Processing Record 1 of Set 16 | kimbe
# Processing Record 2 of Set 16 | tigzirt
# Processing Record 3 of Set 16 | aksarka
# Processing Record 4 of Set 16 | puerto ayacucho
# Processing Record 5 of Set 16 | callaway
# Processing Record 6 of Set 16 | craig
# Processing Record 7 of Set 16 | nagorsk
# Processing Record 8 of Set 16 | weligama
# Processing Record 9 of Set 16 | indramayu
# Processing Record 10 of Set 16 | cockburn town
# Processing Record 11 of Set 16 | eucaliptus
# Processing Record 12 of Set 16 | teknaf
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Rafai   4.9500   23.9167     72.75        92         100        0.54
# 1  Georgetown   5.4112  100.3354     84.13        86          40        5.75
# 2     Isangel -19.5500  169.2667     78.91        69          40        9.22
# 3        Lebu -37.6167  -73.6500     49.17        93           8       15.84
# 4     Mataura -46.1927  168.8643     56.48        59           5        1.10
# 5      Luanda  -8.8368   13.2343     77.00        83         100        8.05
# 6   Rongcheng  30.6340  117.8517     74.64        42           0        7.00
# 7       Vaini -21.2000 -175.2000     77.16        83          20        4.61
# 8    Thompson  55.7435  -97.8558     35.76       100         100        8.05
# 9   Busselton -33.6500  115.3333     63.34        54          24       11.05
#
#   Country       Description
# 0      CF   overcast clouds
# 1      MY  scattered clouds
# 2      VU  scattered clouds
# 3      CL         clear sky
# 4      NZ         clear sky
# 5      AO   overcast clouds
# 6      CN         clear sky
# 7      TO        few clouds
# 8      CA        light rain
# 9      AU        few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"]


# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_order]

# Display sample data
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rafai      CF   4.9500   23.9167     72.75        92         100
# 1  Georgetown      MY   5.4112  100.3354     84.13        86          40
# 2     Isangel      VU -19.5500  169.2667     78.91        69          40
# 3        Lebu      CL -37.6167  -73.6500     49.17        93           8
# 4     Mataura      NZ -46.1927  168.8643     56.48        59           5
#
#    Wind Speed       Description
# 0        0.54   overcast clouds
# 1        5.75  scattered clouds
# 2        9.22  scattered clouds
# 3       15.84         clear sky
# 4        1.10         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file)
